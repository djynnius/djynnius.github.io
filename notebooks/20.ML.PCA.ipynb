# %% [markdown]
# # Principal Component Analysis

# %%
import numpy as np
import pandas as pd

from matplotlib import pyplot as plt 
import seaborn as sns

import cufflinks as cf

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.11.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
#titanic.drop(columns=['deck'], inplace=True)
#titanic.age = titanic.age.fillna(titanic.age.mean())
#titanic.dropna(inplace=True)

# %%
unlabelled  = titanic.drop(['survived', 'alive'], axis=1)

# %%
unlabelled = pd.get_dummies(unlabelled, drop_first=True)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaled = scaler.fit(unlabelled)

# %%
scaled = scaler.transform(unlabelled)

# %%
xscaled = pd.DataFrame(scaled)

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=3)

# %%
pca.fit(scaled)
# Out:
# PCA(n_components=3)

# %%
eigen = pca.transform(scaled)

# %%
xeigen = pd.DataFrame(eigen)

# %%
#xeigen

# %%
pd.concat([xeigen, titanic.survived, titanic.alive], axis=1).iplot(kind='scatter3d', x=0, y=1, z=2, categories='alive')
# Out:
# <div>                            <div id="afbbf8f8-af89-42dd-83c6-b62c29025e6f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("afbbf8f8-af89-42dd-83c6-b62c29025e6f")) {                    Plotly.newPlot(                        "afbbf8f8-af89-42dd-83c6-b62c29025e6f",                        [{"marker":{"color":"rgba(255, 153, 51, 1.0)","line":{"width":1.3},"opacity":0.8,"size":12,"symbol":"circle"},"mode":"markers","name":"no","textfont":{"color":"#4D5663"},"x":[-1.445368244002719,-2.2286848361163343,-1.3015720069314363,-1.6694868368608142,1.1521953213262786,-2.134502464358329,-0.09577507278299383,0.6531110642933698,2.2241856663895847,2.1516107242174245,-1.692312662366635,2.0184915184448644,-1.69990951651093,0.8558327338901314,-2.1959497650834305,-1.1689911414346787,-1.9420647076259738,-0.19551831913652865,-0.8891158955214201,-2.140781289142196,2.384227083561978,2.064791638834918,2.6599451822287894,-1.6975245638435488,-2.195401524622324,-0.5719998696678978,-0.792991446256851,2.2325243692856382,1.3379674492327072,-2.141670135544768,-0.37643238673091783,-1.6923655342902415,1.7636700166173813,-1.6515531731951056,1.4380861892004189,-1.1043137060213333,-0.6926732905446984,3.2050346939340786,-1.728584664974495,3.5008763100331945,-1.435528298903826,-0.9464446328846692,-2.037604861565853,-2.1959497650834305,-2.195401524622324,1.4814790785187821,-2.185856578278215,1.9808657027478624,-2.195401524622324,4.445985430719014,-2.1910118874131324,-2.1351986088608235,-0.8816105316824977,-0.8747420085777817,-2.3822209394173735,-2.195401524622324,-1.338983799144187,-0.10781851351335461,1.4299866928739797,-2.1959497650834305,-0.5441623879426817,-2.2139790225628646,-1.3861590933194978,-2.1852813030903717,1.47306455257804,3.0740222118254437,1.8763985765807933,-2.147060113926063,2.191612519475859,2.0208111848039128,-2.141225712343482,-1.5602718778804932,-0.9678804633032968,0.540671364157405,2.517604048178944,-0.580000483337969,-2.195401524622324,-0.45918095701315076,1.8924323826236427,0.9767048164456233,-2.1628471202436215,-1.7182502257698253,-2.1380578499686167,2.0387056780395447,2.6651644607124947,-1.1574879687725632,3.1765066694968236,-2.105239096831338,-0.8855015379836786,3.045786078917032,1.467141266355202,-1.6371257323900685,-0.5749118814509335,-2.1793580168675333,-0.5998203369818222,-1.7824844487874454,-1.8406826800071354,2.903637226030475,-1.1383755726806337,-2.198023621509911,-0.29066207112295206,2.3971326938649193,-2.1932238509360227,0.3330983502052442,-1.4288458530993682,1.8551185071729315,-2.1134883163204266,1.375640397935909,0.9274961849423649,-1.60912366874017,-2.0124895624303845,-1.7787243786167928,2.2116280168218507,1.7251134405015718,-1.2588750657859449,-1.1439217702298545,-0.852775976691826,2.387014482600725,-1.707138551381041,-2.2635845150630183,3.948366346169595,-1.1995356220653939,1.5700831097512442,1.5437657980653066,3.043268126296454,-2.235511901361308,1.8955717950155762,2.190884390298971,-1.4436497401112873,2.311177709405148,-2.179577753494348,0.3330983502052442,-2.227931791647977,-1.7991204882355443,-2.121944814790595,-1.4775801755929139,-1.6355742588311846,1.9051784055462775,-1.707138551381041,-0.5995541081476283,3.511500627575736,2.6691957317393373,-2.109387165222861,-2.329146032658207,-2.1959497650834305,-0.7288959431950156,-1.6469599427842232,-1.6317926539746368,2.7624920192725266,2.88200963601381,-1.887446777308041,2.4991675547085,1.4180887785368832,-1.0442859070098631,2.3306517402119518,-1.728552680300101,2.64559725151889,3.043268126296454,-2.1503488456155795,-1.701798704085605,0.27680059900227144,1.4483936766438579,3.0530460342625583,-2.1982458331105543,2.4115526653992743,-1.8097131333921601,-1.464133679622608,2.494063151190554,3.050175716126224,1.6077560584544466,-1.7659744761002265,2.311177709405148,-1.7536999641099629,-0.5652095524513,-1.462338140908919,-2.194517442440481,2.311177709405148,-1.7514693767401075,2.1927915424702498,2.408678053356764,-2.1854292071317594,-2.1042318560879436,-2.128223639574462,-1.715524311 ...

# %%
from sklearn.model_selection import train_test_split

# %%
feat_train, feat_test, lab_train, lab_test = train_test_split(xeigen, titanic.survived, test_size=0.2, random_state=101)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=7)
knn.fit(feat_train, lab_train)
kpred = knn.predict(feat_test)

# %%
dtc = DecisionTreeClassifier()
dtc.fit(feat_train, lab_train)
dpred = dtc.predict(feat_test)

# %%
svc = SVC()
svc.fit(feat_train, lab_train)
spred = svc.predict(feat_test)

# %%
rfc = RandomForestClassifier(n_estimators=500)
rfc.fit(feat_train, lab_train)
rpred = rfc.predict(feat_test)

# %%
logit = LogisticRegression()
logit.fit(feat_train, lab_train)
lpred = logit.predict(feat_test)

# %%
xgb = XGBClassifier()
xgb.fit(feat_train, lab_train)
xpred = xgb.predict(feat_test)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(kpred, lab_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.80      0.87       126
#            1       0.65      0.88      0.75        52
#
#     accuracy                           0.83       178
#    macro avg       0.80      0.84      0.81       178
# weighted avg       0.86      0.83      0.83       178

# %%
print(classification_report(spred, lab_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.80      0.86       125
#            1       0.65      0.87      0.74        53
#
#     accuracy                           0.82       178
#    macro avg       0.79      0.83      0.80       178
# weighted avg       0.85      0.82      0.83       178

# %%
print(classification_report(dpred, lab_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.78      0.75       100
#            1       0.69      0.63      0.66        78
#
#     accuracy                           0.71       178
#    macro avg       0.71      0.70      0.71       178
# weighted avg       0.71      0.71      0.71       178

# %%
print(classification_report(rpred, lab_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.82      0.82       109
#            1       0.72      0.74      0.73        69
#
#     accuracy                           0.79       178
#    macro avg       0.78      0.78      0.78       178
# weighted avg       0.79      0.79      0.79       178

# %%
print(classification_report(lpred, lab_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.82      0.87       119
#            1       0.70      0.85      0.77        59
#
#     accuracy                           0.83       178
#    macro avg       0.81      0.84      0.82       178
# weighted avg       0.85      0.83      0.83       178

# %%
print(classification_report(xpred, lab_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.82      0.82       109
#            1       0.72      0.74      0.73        69
#
#     accuracy                           0.79       178
#    macro avg       0.78      0.78      0.78       178
# weighted avg       0.79      0.79      0.79       178

# %% [markdown]
# # Performance (based on accuracy)
# 1. Logistic regression - 83%
# 2. K-Nearest Neighbor - 83%
# 3. Support Vector Machine - 82%
# 4. XGBoot - 79%
# 5. Random Forest - 79%
# 6. Decision tree - 71%
