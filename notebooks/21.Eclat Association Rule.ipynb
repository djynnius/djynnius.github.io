# %%
import pandas as pd
from functools import reduce

# %%
shopping = pd.read_csv("datasets/Market_Basket_Optimisation.csv", header=None, sep="\t")
s = pd.read_csv("datasets/Market_Basket_Optimisation.csv", header=None, sep="\t")

# %%
shopping
#shopping.head()
shopping.shape
# Out:
# (7501, 1)

# %%
shopping.rename(columns={0: 'items'}, inplace=True)
s.rename(columns={0: 'items'}, inplace=True)

# %%
shopping
# Out:
#                                                   items
# 0     shrimp,almonds,avocado,vegetables mix,green gr...
# 1                                burgers,meatballs,eggs
# 2                                               chutney
# 3                                        turkey,avocado
# 4     mineral water,milk,energy bar,whole wheat rice...
# ...                                                 ...
# 7496                      butter,light mayo,fresh bread
# 7497  burgers,frozen vegetables,eggs,french fries,ma...
# 7498                                            chicken
# 7499                                 escalope,green tea
# 7500    eggs,frozen smoothie,yogurt cake,low fat yogurt
#
# [7501 rows x 1 columns]

# %% [markdown]
# ### Clean items

# %%
def clean_items(x):
    items = x['items'].lower() #make all lowercase
    items = list(set(items.split(","))) #remove duplicates
    items = sorted(items) #sort
    items = [item.replace(' ', '-') for item in items]
    items = ','.join(items)
    return items

# %%
shopping['clean_items'] = shopping.apply(clean_items, axis=1)

# %%
shopping
# Out:
#                                                   items  \
# 0     shrimp,almonds,avocado,vegetables mix,green gr...
# 1                                burgers,meatballs,eggs
# 2                                               chutney
# 3                                        turkey,avocado
# 4     mineral water,milk,energy bar,whole wheat rice...
# ...                                                 ...
# 7496                      butter,light mayo,fresh bread
# 7497  burgers,frozen vegetables,eggs,french fries,ma...
# 7498                                            chicken
# 7499                                 escalope,green tea
# 7500    eggs,frozen smoothie,yogurt cake,low fat yogurt
#
#                                             clean_items
# 0     almonds,antioxydant-juice,avocado,cottage-chee...
# 1                                burgers,eggs,meatballs
# 2                                               chutney
# 3                                        avocado,turkey
# 4     energy-bar,green-tea,milk,mineral-water,whole-...
# ...                                                 ...
# 7496                      butter,fresh-bread,light-mayo
# 7497  burgers,eggs,french-fries,frozen-vegetables,gr...
# 7498                                            chicken
# 7499                                 escalope,green-tea
# 7500    eggs,frozen-smoothie,low-fat-yogurt,yogurt-cake
#
# [7501 rows x 2 columns]

# %% [markdown]
# ### Get number of items in each set

# %%
def length(x):
    return len(x['clean_items'].split(","))

# %%
shopping['length'] = shopping.apply(length, axis=1)

# %%
shopping.sort_values('clean_items')
# Out:
#                                                   items  \
# 694   burgers,chocolate,shrimp,whole wheat pasta,gro...
# 7453                                            almonds
# 253                                             almonds
# 0     shrimp,almonds,avocado,vegetables mix,green gr...
# 1774  burgers,ground beef,spaghetti,avocado,milk,oli...
# ...                                                 ...
# 3553                                        yogurt cake
# 402                                         yogurt cake
# 5611                                        yogurt cake
# 5427                                        yogurt cake
# 5169                                        yogurt cake
#
#                                             clean_items  length
# 694   -asparagus,burgers,chocolate,energy-bar,ground...       8
# 7453                                            almonds       1
# 253                                             almonds       1
# 0     almonds,antioxydant-juice,avocado,cottage-chee...      20
# 1774  almonds,avocado,burgers,cake,chocolate,frozen-...      13
# ...                                                 ...     ...
# 3553                                        yogurt-cake       1
# 402                                         yogurt-cake       1
# 5611                                        yogurt-cake       1
# 5427                                        yogurt-cake       1
# 5169                                        yogurt-cake       1
#
# [7501 rows x 3 columns]

# %% [markdown]
# ### Get frequency of each item

# %%
item_freq = shopping[['clean_items', 'items']].groupby('clean_items').count()

# %%
item_freq = item_freq.reset_index().rename(columns={'items': 'count'})

# %%
item_freq
# Out:
#                                             clean_items  count
# 0     -asparagus,burgers,chocolate,energy-bar,ground...      1
# 1                                               almonds      2
# 2     almonds,antioxydant-juice,avocado,cottage-chee...      1
# 3     almonds,avocado,burgers,cake,chocolate,frozen-...      1
# 4     almonds,avocado,burgers,cauliflower,green-tea,...      1
# ...                                                 ...    ...
# 5149                                  whole-wheat-pasta      7
# 5150                         whole-wheat-pasta,zucchini      1
# 5151                                   whole-wheat-rice     18
# 5152                                               yams      8
# 5153                                        yogurt-cake     25
#
# [5154 rows x 2 columns]

# %%
shopping = shopping.merge(item_freq, left_on='clean_items', right_on='clean_items')

# %%
#shopping.sort_values('count', ascending=False).head(25)

# %% [markdown]
# ### Calculate support

# %%
shopping.shape[0]
# Out:
# 7501

# %%
def support(x):
    return x['count']/shopping.shape[0]

# %%
shopping['support'] = shopping.apply(support, axis=1)

# %%
duplicates = shopping.clean_items.duplicated()
shopping = shopping.loc[~duplicates]

# %%
shopping.sort_values(['support', 'length'], ascending=[False, False])
# Out:
#                  items       clean_items  length  count   support
# 191            cookies           cookies       1    223  0.029729
# 56        french fries      french-fries       1    132  0.017598
# 700           escalope          escalope       1    101  0.013465
# 424      mineral water     mineral-water       1     93  0.012398
# 540               eggs              eggs       1     90  0.011998
# ...                ...               ...     ...    ...       ...
# 6601  hand protein bar  hand-protein-bar       1      1  0.000133
# 6897             bacon             bacon       1      1  0.000133
# 7027         flax seed         flax-seed       1      1  0.000133
# 7141      green grapes      green-grapes       1      1  0.000133
# 7473             cider             cider       1      1  0.000133
#
# [5154 rows x 5 columns]

# %%
shopping
# Out:
#                                                   items  \
# 0     shrimp,almonds,avocado,vegetables mix,green gr...
# 1                                burgers,meatballs,eggs
# 2                                               chutney
# 4                                        turkey,avocado
# 6     mineral water,milk,energy bar,whole wheat rice...
# ...                                                 ...
# 7496  burgers,salmon,pancakes,french fries,frozen sm...
# 7497  turkey,burgers,dessert wine,shrimp,pasta,tomat...
# 7498                      butter,light mayo,fresh bread
# 7499  burgers,frozen vegetables,eggs,french fries,ma...
# 7500    eggs,frozen smoothie,yogurt cake,low fat yogurt
#
#                                             clean_items  length  count  \
# 0     almonds,antioxydant-juice,avocado,cottage-chee...      20      1
# 1                                burgers,eggs,meatballs       3      1
# 2                                               chutney       1      2
# 4                                        avocado,turkey       2      2
# 6     energy-bar,green-tea,milk,mineral-water,whole-...       5      1
# ...                                                 ...     ...    ...
# 7496  burgers,french-fries,fresh-bread,frozen-smooth...       7      1
# 7497  burgers,dessert-wine,frozen-smoothie,milk,oil,...      12      1
# 7498                      butter,fresh-bread,light-mayo       3      1
# 7499  burgers,eggs,french-fries,frozen-vegetables,gr...       6      1
# 7500    eggs,frozen-smoothie,low-fat-yogurt,yogurt-cake       4      1
#
#        support
# 0     0.000133
# 1     0.000133
# 2     0.000267
# 4     0.000267
# 6     0.000133
# ...        ...
# 7496  0.000133
# 7497  0.000133
# 7498  0.000133
# 7499  0.000133
# 7500  0.000133
#
# [5154 rows x 5 columns]

# %%
def recommend(x, search):
    search = set([a.lower().replace(' ', '-') for a in search])
    basket = set(x['clean_items'].split(","))
    return ','.join(list(basket.difference(search))) if search.issubset(basket) else ''

# %%
shopping['recommended'] = shopping.apply(recommend, args=(['eggs', 'turkey'], ), axis=1)

# %%
shopping.loc[shopping['recommended'] != '']
# Out:
#                                                   items  \
# 414       turkey,burgers,mineral water,eggs,cooking oil
# 534   turkey,fresh tuna,tomatoes,spaghetti,mineral w...
# 999   turkey,burgers,ground beef,chocolate,soup,almo...
# 1237  turkey,burgers,chocolate,olive oil,eggs,cookin...
# 1260  turkey,eggs,chocolate,frozen smoothie,tomato j...
# ...                                                 ...
# 7196           turkey,burgers,spaghetti,milk,eggs,honey
# 7266                           turkey,green grapes,eggs
# 7372  turkey,frozen vegetables,mineral water,eggs,ch...
# 7481  turkey,burgers,grated cheese,shrimp,pasta,spag...
# 7485  turkey,shrimp,pasta,mineral water,chocolate,mi...
#
#                                             clean_items  length  count  \
# 414       burgers,cooking-oil,eggs,mineral-water,turkey       5      1
# 534   black-tea,chicken,eggs,extra-dark-chocolate,fr...      10      1
# 999   almonds,burgers,chocolate,cottage-cheese,eggs,...       9      1
# 1237  burgers,chocolate,cooking-oil,corn,eggs,olive-...       7      1
# 1260  chocolate,eggs,frozen-smoothie,tomato-juice,tu...       5      1
# ...                                                 ...     ...    ...
# 7196           burgers,eggs,honey,milk,spaghetti,turkey       6      1
# 7266                           eggs,green-grapes,turkey       3      1
# 7372  chocolate,eggs,fresh-bread,frozen-vegetables,m...       6      1
# 7481  burgers,chocolate,eggs,grated-cheese,mineral-w...      12      1
# 7485  chocolate,eggs,gluten-free-bar,milk,mineral-wa...      12      1
#
#        support                                        recommended
# 414   0.000133                  mineral-water,cooking-oil,burgers
# 534   0.000133  extra-dark-chocolate,mineral-water,fresh-tuna,...
# 999   0.000133  chocolate,cottage-cheese,ground-beef,soup,hot-...
# 1237  0.000133       chocolate,cooking-oil,burgers,olive-oil,corn
# 1260  0.000133             chocolate,tomato-juice,frozen-smoothie
# ...        ...                                                ...
# 7196  0.000133                       milk,spaghetti,honey,burgers
# 7266  0.000133                                       green-grapes
# 7372  0.000133  chocolate,mineral-water,frozen-vegetables,fres...
# 7481  0.000133  chocolate,grated-cheese,mineral-water,yogurt-c...
# 7485  0.000133  chocolate,sparkling-water,mineral-water,milk,v...
#
# [128 rows x 6 columns]

# %% [markdown]
# # Piping

# %%
def Eclat(df, min_len, search):
    
    original_length = df.shape[0]
    
    def clean_items(x):
        items = x['items'].lower() #make all lowercase
        items = list(set(items.split(","))) #remove duplicates
        items = sorted(items) #sort
        items = [item.replace(' ', '-') for item in items]
        items = ','.join(items)
        return items 
    
    df['clean_items'] = df.apply(clean_items, axis=1)

    def length(x):
        return len(x['clean_items'].split(","))    
    df['length'] = df.apply(length, axis=1)
    
    item_freq = df[['clean_items', 'items']].groupby('clean_items').count()
    item_freq = item_freq.reset_index().rename(columns={'items': 'count'})
    df = df.merge(item_freq, left_on='clean_items', right_on='clean_items')
    
    dupes = df.duplicated() #remvoe duplicates
    df = df.loc[~dupes]
    
    def support(x):
        return x['count']/original_length    
    
    df['support'] = df.apply(support, axis=1)
    
    df =  df.loc[df['length'] > min_len].sort_values(['support', 'length'], ascending=[False, False])

    def recommend(x, search):
        search = set([item.lower().replace(' ', '-') for item in search])
        basket = set(x['clean_items'].split(","))
        return ','.join(list(basket.difference(search))) if search.issubset(basket) else '' 
    
    df['recommended'] = df.apply(recommend, args =(search,), axis=1)
    return df.loc[df['recommended'] != '']

# %%
s.pipe(Eclat, min_len=2, search=['burgers'])
# Out:
#                                       items  \
# 2279              burgers,eggs,french fries
# 3643                 burgers,eggs,green tea
# 4060             burgers,mineral water,eggs
# 4019     burgers,eggs,french fries,pancakes
# 867                burgers,escalope,shallot
# ...                                     ...
# 7304                 burgers,escalope,pasta
# 7345           burgers,fresh tuna,chocolate
# 7374  burgers,mineral water,chocolate bread
# 7377                turkey,burgers,pet food
# 7380                    turkey,burgers,cake
#
#                                 clean_items  length  count   support  \
# 2279              burgers,eggs,french-fries       3      9  0.001200
# 3643                 burgers,eggs,green-tea       3      3  0.000400
# 4060             burgers,eggs,mineral-water       3      3  0.000400
# 4019     burgers,eggs,french-fries,pancakes       4      2  0.000267
# 867                burgers,escalope,shallot       3      2  0.000267
# ...                                     ...     ...    ...       ...
# 7304                 burgers,escalope,pasta       3      1  0.000133
# 7345           burgers,chocolate,fresh-tuna       3      1  0.000133
# 7374  burgers,chocolate-bread,mineral-water       3      1  0.000133
# 7377                burgers,pet-food,turkey       3      1  0.000133
# 7380                    burgers,cake,turkey       3      1  0.000133
#
#                         recommended
# 2279              eggs,french-fries
# 3643                 eggs,green-tea
# 4060             eggs,mineral-water
# 4019     eggs,pancakes,french-fries
# 867                shallot,escalope
# ...                             ...
# 7304                 escalope,pasta
# 7345           chocolate,fresh-tuna
# 7374  chocolate-bread,mineral-water
# 7377                turkey,pet-food
# 7380                    cake,turkey
#
# [563 rows x 6 columns]

# %%
def apriori(df, result_count):
    #df = [(a[1].recommended.split(","), a[1].support) for a in df[['support', 'recommended']].iterrows()]
    df = [item.split(",") for item in df['recommended']]
    df = reduce(lambda x,y: x+y, df)
    
    df = pd.DataFrame([{'item': i, 'count':df.count(i)} for i in df])
    dupes = df.duplicated()
    df = df[~dupes]
    #df = df.sort_values('count', ascending=False)
    return df.head(result_count)

# %%
#s.pipe(Eclat, min_len=2, search=['frozen-vegetables', 'salmon']).pipe(apriori, result_count=10)

# %%
movies = pd.read_csv("movies_viewing.csv")

# %%
users = movies[['userId', 'title']].userId.value_counts()

# %%
# Out:
# 3
